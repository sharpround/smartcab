# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
ls *pickle
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is B277-9DA9
#
#  Directory of C:\Users\db161_000\Dropbox\Projects\data_science\mlnd\smartcab
#
# 2016-03-19  08:08             9,696 convergence_14.pickle
# 2016-03-19  11:17             2,968 convergence_g4a8.pickle
# 2016-03-19  10:46             1,816 convergence_g4a8e1.pickle
# 2016-03-19  09:45             1,308 convergence_g5a3eR.pickle
# 2016-03-19  10:23             1,648 convergence_g5aReR.pickle
# 2016-03-19  08:39            12,670 convergence_g6a3eR.pickle
# 2016-03-19  08:08            25,416 qtable_14.pickle
# 2016-03-19  11:17            25,416 qtable_g4a8.pickle
# 2016-03-19  10:46            25,416 qtable_g4a8e1.pickle
# 2016-03-19  09:45            25,416 qtable_g5a3eR.pickle
# 2016-03-19  10:23            25,416 qtable_g5aReR.pickle
# 2016-03-19  08:39            25,416 qtable_g6a3eR.pickle
# 2016-03-18  10:34            25,416 qtable2.pickle
# 2016-03-18  10:48            25,416 qtable3.pickle
# 2016-03-18  10:58            25,416 qtable4.pickle
# 2016-03-18  11:04            25,416 qtable5.pickle
# 2016-03-18  11:11            25,416 qtable6.pickle
# 2016-03-19  08:08             1,493 success_14.pickle
# 2016-03-19  11:17             1,541 success_g4a8.pickle
# 2016-03-19  10:46             1,781 success_g4a8e1.pickle
# 2016-03-19  09:45               620 success_g5a3eR.pickle
# 2016-03-19  10:23             1,613 success_g5aReR.pickle
# 2016-03-19  08:39             1,781 success_g6a3eR.pickle
# 2016-03-18  10:34               716 success2.pickle
# 2016-03-18  10:48               668 success3.pickle
# 2016-03-18  10:58               932 success4.pickle
# 2016-03-18  11:04               576 success5.pickle
# 2016-03-18  11:11               692 success6.pickle
# 2016-03-18  10:01               788 test1.pickle
#               29 File(s)        322,883 bytes
#                0 Dir(s)  22,287,736,832 bytes free

# %%
success = pd.read_pickle('success_02.pickle')
success.hist(bins=range(0, 101, 10))
plt.xlabel("trial number")
plt.ylabel("# of successes")
plt.title("success frequency, 100 trials")

# %%
conv = pd.read_pickle('convergence_02.pickle')
plt.plot(conv)
plt.hold(True)
plt.plot([0.0, 100.0], [0.7, 0.1])
